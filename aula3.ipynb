# %% [markdown]
# # Parte 1 - Escolas

# %%
import pandas as pd

# %%
url = "https://drive.google.com/uc?id=15aOJIGAyLMSY1gecjiCgu2ko_riIcKQy"

alunos = pd.read_csv(url)

# %%
url2 = "https://drive.google.com/uc?id=1Jgto7psHaMRTAVzcFt7D6SgJiHMB7uGT"
escolas = pd.read_csv(url2)

# %%
alunos
# Out:
#        ID_Estudante       Nome_Estudante Genero  Serie Nome_Escola  \
# 0                 0        Kevin Bradley      M      6    Escola A
# 1                 1           Paul Smith      M      9    Escola A
# 2                 2       John Rodriguez      M      9    Escola A
# 3                 3         Oliver Scott      M      9    Escola A
# 4                 4          William Ray      F      6    Escola A
# ...             ...                  ...    ...    ...         ...
# 39155         39155          John Brooks      M      7    Escola O
# 39156         39156  Stephanie Contreras      F      8    Escola O
# 39157         39157     Kristen Gonzalez      F      6    Escola O
# 39158         39158        Kari Holloway      F      7    Escola O
# 39159         39159     Kimberly Cabrera      F      8    Escola O
#
#        Nota_Redacao  Nota_Matematica
# 0                66               79
# 1                94               61
# 2                90               60
# ...

# %%
escolas
# Out:
#     ID_Escola Nome_Escola Tipo_Escola  Numero_Alunos  Orcamento_Anual
# 0           0    Escola A     Publica           2917          1910635
# 1           1    Escola B     Publica           2949          1884411
# 2           2    Escola C  Particular           1761          1056600
# 3           3    Escola D     Publica           4635          3022020
# 4           4    Escola E  Particular           1468           917500
# 5           5    Escola F  Particular           2283          1319574
# 6           6    Escola G  Particular           1858          1081356
# 7           7    Escola H     Publica           4976          3124928
# 8           8    Escola I  Particular            427           248087
# 9           9    Escola J  Particular            962           585858
# 10         10    Escola K  Particular           1800          1049400
# 11         11    Escola L     Publica           3999          2547363
# ...

# %% [markdown]
# ## Verificar NULL e DUPLICATED

# %%
alunos.isnull().sum()
# Out:
# ID_Estudante       0
# Nome_Estudante     0
# Genero             0
# Serie              0
# Nome_Escola        0
# Nota_Redacao       0
# Nota_Matematica    0
# dtype: int64

# %%
alunos.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Pandas merge

# %%
dataMerge = pd.merge(alunos, escolas)

# %%
dataMerge
# Out:
#        ID_Estudante       Nome_Estudante Genero  Serie Nome_Escola  \
# 0                 0        Kevin Bradley      M      6    Escola A
# 1                 1           Paul Smith      M      9    Escola A
# 2                 2       John Rodriguez      M      9    Escola A
# 3                 3         Oliver Scott      M      9    Escola A
# 4                 4          William Ray      F      6    Escola A
# ...             ...                  ...    ...    ...         ...
# 39155         39155          John Brooks      M      7    Escola O
# 39156         39156  Stephanie Contreras      F      8    Escola O
# 39157         39157     Kristen Gonzalez      F      6    Escola O
# 39158         39158        Kari Holloway      F      7    Escola O
# 39159         39159     Kimberly Cabrera      F      8    Escola O
#
#        Nota_Redacao  Nota_Matematica  ID_Escola Tipo_Escola  Numero_Alunos  \
# 0                66               79          0     Publica           2917
# ...

# %% [markdown]
# Pergunta Importante: Qual é o dicionario de dados

# %% [markdown]
# ## Variáveis categóricas

# %%
dataMerge["Serie"].unique()
# Out:
# array([6, 9, 8, 7])

# %%
dataMerge["Tipo_Escola"].unique()
# Out:
# <StringArray>
# ['Publica', 'Particular']
# Length: 2, dtype: str

# %%
dataMerge["Nome_Escola"].unique()
# Out:
# <StringArray>
# ['Escola A', 'Escola B', 'Escola C', 'Escola D', 'Escola E', 'Escola F',
#  'Escola G', 'Escola H', 'Escola I', 'Escola J', 'Escola K', 'Escola L',
#  'Escola M', 'Escola N', 'Escola O']
# Length: 15, dtype: str

# %%
dataMerge['Tipo_Escola']
# Out:
# 0           Publica
# 1           Publica
# 2           Publica
# 3           Publica
# 4           Publica
#             ...
# 39155    Particular
# 39156    Particular
# 39157    Particular
# 39158    Particular
# 39159    Particular
# Name: Tipo_Escola, Length: 39160, dtype: str

# %%
dataMerge['Tipo_Escola'].unique()
# Out:
# <StringArray>
# ['Publica', 'Particular']
# Length: 2, dtype: str

# %%
dataMerge["Tipo_Escola"].value_counts()
# Out:
# Tipo_Escola
# Publica       26976
# Particular    12184
# Name: count, dtype: int64

# %%
dataMerge.Nome_Escola.value_counts(sort=False)
# Out:
# Nome_Escola
# Escola A    2917
# Escola B    2949
# Escola C    1761
# Escola D    4635
# Escola E    1468
# Escola F    2283
# Escola G    1858
# Escola H    4976
# Escola I     427
# Escola J     962
# Escola K    1800
# Escola L    3999
# Escola M    4761
# Escola N    2739
# Escola O    1625
# Name: count, dtype: int64

# %% [markdown]
# ## Quantos alunos ficaram com nota maior que 90 em redação

# %% [markdown]
# Verificação cruzada dataMerge[dataMerge] => Você precisa referenciar novamente

# %%
dataMerge[dataMerge["Nota_Redacao"]==77]
# Out:
#        ID_Estudante    Nome_Estudante Genero  Serie Nome_Escola  Nota_Redacao  \
# 47               47       Ellen Brown      F      8    Escola A            77
# 63               63     Ronnie Conley      M      8    Escola A            77
# 66               66   Dylan Taylor MD      M      7    Escola A            77
# 84               84     Joseph Butler      M      7    Escola A            77
# 96               96     Jessica Smith      F      6    Escola A            77
# ...             ...               ...    ...    ...         ...           ...
# 39050         39050      Michael Reed      M      9    Escola O            77
# 39051         39051      Matthew Ball      M      8    Escola O            77
# 39072         39072    Amanda Ramirez      F      9    Escola O            77
# 39133         39133       Emily Gomez      F      9    Escola O            77
# 39144         39144  Cristian Webster      M      9    Escola O            77
#
# ...

# %% [markdown]
# ### Função filtrar nota

# %%
def grade_filter(subject, grade):
    print("A disciplina escolhida, foi:", subject)
    print("A nota escolhida", grade)
    print("Número de alunos: ", len(dataMerge[dataMerge[subject]>=grade]))
    return dataMerge[dataMerge[subject]>=grade]

# %%
grade_filter("Nota_Redacao", 77)
# Out:
# A disciplina escolhida, foi: Nota_Redacao
# A nota escolhida 77
# Número de alunos:  25845
#        ID_Estudante       Nome_Estudante Genero  Serie Nome_Escola  \
# 1                 1           Paul Smith      M      9    Escola A
# 2                 2       John Rodriguez      M      9    Escola A
# 4                 4          William Ray      F      6    Escola A
# 5                 5        James Miranda      M      6    Escola A
# 6                 6      Benjamin Carter      F      8    Escola A
# ...             ...                  ...    ...    ...         ...
# 39155         39155          John Brooks      M      7    Escola O
# 39156         39156  Stephanie Contreras      F      8    Escola O
# 39157         39157     Kristen Gonzalez      F      6    Escola O
# 39158         39158        Kari Holloway      F      7    Escola O
# 39159         39159     Kimberly Cabrera      F      8    Escola O
#
# ...

# %% [markdown]
# Mostrar a porcentagem do filtro

# %%
def grade_filter_percent(subject: str, grade: int):
    print("A disciplina escolhida, foi:", subject)
    print("A nota escolhida", grade)
    print("Número de alunos: ", len(dataMerge[dataMerge[subject]>=grade]))
    return len(dataMerge[dataMerge[subject]>grade])/len(alunos)*100

# %%
grade_filter_percent("Nota_Redacao", 95)
# Out:
# A disciplina escolhida, foi: Nota_Redacao
# A nota escolhida 95
# Número de alunos:  5477
# 11.115934627170581

# %% [markdown]
# Filtro de filtro

# %%
dataMerge[(dataMerge["Nota_Redacao"] > 90) & (dataMerge["Nota_Matematica"] > 90)]
# Out:
#        ID_Estudante    Nome_Estudante Genero  Serie Nome_Escola  Nota_Redacao  \
# 5                 5     James Miranda      M      6    Escola A            94
# 30               30      Bobby Harris      M      6    Escola A            94
# 91               91       Mark Cherry      M      7    Escola A            96
# 133             133       Marisa Lowe      F      6    Escola A            95
# 181             181  Matthew Anderson      M      8    Escola A            92
# ...             ...               ...    ...    ...         ...           ...
# 39091         39091    Jeremy Edwards      M      7    Escola O            91
# 39121         39121  Stephanie Wilson      F      7    Escola O            94
# 39127         39127       Robert Wood      M      6    Escola O            97
# 39138         39138    Monica Hampton      F      6    Escola O            94
# 39155         39155       John Brooks      M      7    Escola O            92
#
# ...

# %%
high_both = dataMerge[(dataMerge["Nota_Redacao"] > 90) & (dataMerge["Nota_Matematica"] > 90)]

# %% [markdown]
# filtro do filtro

# %%
high_both["Tipo_Escola"].value_counts()
# Out:
# Tipo_Escola
# Publica       1321
# Particular    1002
# Name: count, dtype: int64
